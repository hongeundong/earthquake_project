# %%
import pandas as pd

# %%
data1 = pd.read_csv('datasets/地震リスト (1).csv')
data1
# Out:
#          地震の発生日     地震の発生時刻     震央地名         緯度          経度     深さ    Ｍ 最大震度
# 0    2023/05/20  23:11:21.2   千葉県南東沖  34°57.6′N  140°13.1′E  79 km  4.2  震度２
# 1    2023/05/20  12:21:40.2  トカラ列島近海  29°55.8′N  130°02.6′E  11 km  2.3  震度１
# 2    2023/05/20  11:27:55.8  トカラ列島近海  29°55.8′N  130°01.1′E   9 km  2.2  震度１
# 3    2023/05/20  04:13:49.5      三陸沖  39°37.6′N  144°28.4′E  54 km  4.7  震度１
# 4    2023/05/20  00:57:58.0   与那国島近海  24°21.6′N  122°59.1′E  48 km  3.2  震度１
# ..          ...         ...      ...        ...         ...    ...  ...  ...
# 995  2022/11/09  09:18:47.7     宮城県沖  38°27.3′N  141°53.3′E  55 km  4.0  震度１
# 996  2022/11/09  05:28:59.1   奄美大島近海  27°58.6′N  129°09.4′E  17 km  3.2  震度１
# 997  2022/11/09  02:38:10.6    宮古島近海  24°49.2′N  125°22.7′E  49 km  3.9  震度２
# 998  2022/11/08  17:38:53.7  石川県能登地方  37°30.1′N  137°12.6′E  13 km  3.0  震度１
# 999  2022/11/08  14:14:00.9  トカラ列島近海  29°37.6′N  129°45.7′E   8 km  3.6  震度３
#
# [1000 rows x 8 columns]

# %%
data2 = pd.read_csv('datasets/地震リスト (2).csv')
data2
# Out:
#          地震の発生日     地震の発生時刻     震央地名         緯度          経度     深さ    Ｍ 最大震度
# 0    2022/11/06  19:44:26.2    大分県中部  33°17.2′N  131°27.6′E   8 km  1.6  震度１
# 1    2022/11/06  13:23:32.0   北海道東方沖  43°14.8′N  146°51.9′E  52 km  5.4  震度３
# 2    2022/11/06  09:06:55.8    長野県南部  35°56.3′N  138°06.1′E   5 km  2.7  震度２
# 3    2022/11/06  00:32:02.0      日向灘  31°42.6′N  131°47.3′E  33 km  3.8  震度１
# 4    2022/11/05  14:49:20.6     宮城県沖  37°52.4′N  141°42.4′E  63 km  3.9  震度１
# ..          ...         ...      ...        ...         ...    ...  ...  ...
# 209  2022/09/23  11:03:32.8     苫小牧沖  41°58.3′N  141°51.1′E  44 km  2.8  震度１
# 210  2022/09/23  09:53:51.9    茨城県南部  36°04.5′N  140°12.1′E  83 km  4.7  震度３
# 211  2022/09/23  07:19:24.2  沖縄本島北西沖  26°21.3′N  125°59.1′E  26 km  4.6  震度１
# 212  2022/09/23  02:53:36.8    長野県南部  35°54.3′N  137°39.3′E  11 km  2.6  震度１
# 213  2022/09/23  00:31:33.4  石川県能登地方  37°31.2′N  137°18.4′E  13 km  2.7  震度１
#
# [214 rows x 8 columns]

# %% [markdown]
# ## 3. 데이터 전처리

# %% [markdown]
# ### NULL 처리

# %%
data1.isnull().sum()
# Out:
# 地震の発生日     0
# 地震の発生時刻    0
# 震央地名       0
# 緯度         0
# 経度         0
# 深さ         0
# Ｍ          0
# 最大震度       0
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# 地震の発生日     0
# 地震の発生時刻    0
# 震央地名       0
# 緯度         0
# 経度         0
# 深さ         0
# Ｍ          0
# 最大震度       0
# dtype: int64

# %% [markdown]
# ### 데이터 피처링

# %%
# 컬럼명 변경 
data1.columns = ['발생일', '발생시각', '위치', '위도', '경도', '깊이(km)', '규모', '진도']
data1
# 컬럼 삭제
# 컬럼 순서 바꾸고
# Out:
#             발생일        발생시각       위치         위도          경도 깊이(km)   규모   진도
# 0    2023/05/20  23:11:21.2   千葉県南東沖  34°57.6′N  140°13.1′E  79 km  4.2  震度２
# 1    2023/05/20  12:21:40.2  トカラ列島近海  29°55.8′N  130°02.6′E  11 km  2.3  震度１
# 2    2023/05/20  11:27:55.8  トカラ列島近海  29°55.8′N  130°01.1′E   9 km  2.2  震度１
# 3    2023/05/20  04:13:49.5      三陸沖  39°37.6′N  144°28.4′E  54 km  4.7  震度１
# 4    2023/05/20  00:57:58.0   与那国島近海  24°21.6′N  122°59.1′E  48 km  3.2  震度１
# ..          ...         ...      ...        ...         ...    ...  ...  ...
# 995  2022/11/09  09:18:47.7     宮城県沖  38°27.3′N  141°53.3′E  55 km  4.0  震度１
# 996  2022/11/09  05:28:59.1   奄美大島近海  27°58.6′N  129°09.4′E  17 km  3.2  震度１
# 997  2022/11/09  02:38:10.6    宮古島近海  24°49.2′N  125°22.7′E  49 km  3.9  震度２
# 998  2022/11/08  17:38:53.7  石川県能登地方  37°30.1′N  137°12.6′E  13 km  3.0  震度１
# 999  2022/11/08  14:14:00.9  トカラ列島近海  29°37.6′N  129°45.7′E   8 km  3.6  震度３
#
# [1000 rows x 8 columns]

# %%
data2.columns = ['발생일', '발생시각', '위치', '위도', '경도', '깊이(km)', '규모', '진도']
data2
# Out:
#             발생일        발생시각       위치         위도          경도 깊이(km)   규모   진도
# 0    2022/11/06  19:44:26.2    大分県中部  33°17.2′N  131°27.6′E   8 km  1.6  震度１
# 1    2022/11/06  13:23:32.0   北海道東方沖  43°14.8′N  146°51.9′E  52 km  5.4  震度３
# 2    2022/11/06  09:06:55.8    長野県南部  35°56.3′N  138°06.1′E   5 km  2.7  震度２
# 3    2022/11/06  00:32:02.0      日向灘  31°42.6′N  131°47.3′E  33 km  3.8  震度１
# 4    2022/11/05  14:49:20.6     宮城県沖  37°52.4′N  141°42.4′E  63 km  3.9  震度１
# ..          ...         ...      ...        ...         ...    ...  ...  ...
# 209  2022/09/23  11:03:32.8     苫小牧沖  41°58.3′N  141°51.1′E  44 km  2.8  震度１
# 210  2022/09/23  09:53:51.9    茨城県南部  36°04.5′N  140°12.1′E  83 km  4.7  震度３
# 211  2022/09/23  07:19:24.2  沖縄本島北西沖  26°21.3′N  125°59.1′E  26 km  4.6  震度１
# 212  2022/09/23  02:53:36.8    長野県南部  35°54.3′N  137°39.3′E  11 km  2.6  震度１
# 213  2022/09/23  00:31:33.4  石川県能登地方  37°31.2′N  137°18.4′E  13 km  2.7  震度１
#
# [214 rows x 8 columns]

# %%
# 컬럼 합치기
data1['발생시각'] = data1['발생일'] + data1['발생시각']
data1
# Out:
#             발생일                  발생시각       위치         위도          경도 깊이(km)  \
# 0    2023/05/20  2023/05/2023:11:21.2   千葉県南東沖  34°57.6′N  140°13.1′E  79 km
# 1    2023/05/20  2023/05/2012:21:40.2  トカラ列島近海  29°55.8′N  130°02.6′E  11 km
# 2    2023/05/20  2023/05/2011:27:55.8  トカラ列島近海  29°55.8′N  130°01.1′E   9 km
# 3    2023/05/20  2023/05/2004:13:49.5      三陸沖  39°37.6′N  144°28.4′E  54 km
# 4    2023/05/20  2023/05/2000:57:58.0   与那国島近海  24°21.6′N  122°59.1′E  48 km
# ..          ...                   ...      ...        ...         ...    ...
# 995  2022/11/09  2022/11/0909:18:47.7     宮城県沖  38°27.3′N  141°53.3′E  55 km
# 996  2022/11/09  2022/11/0905:28:59.1   奄美大島近海  27°58.6′N  129°09.4′E  17 km
# 997  2022/11/09  2022/11/0902:38:10.6    宮古島近海  24°49.2′N  125°22.7′E  49 km
# 998  2022/11/08  2022/11/0817:38:53.7  石川県能登地方  37°30.1′N  137°12.6′E  13 km
# 999  2022/11/08  2022/11/0814:14:00.9  トカラ列島近海  29°37.6′N  129°45.7′E   8 km
#
#       규모   진도
# 0    4.2  震度２
# ...

# %%
data1 = data1.drop('발생일', axis=1)
data1
# Out:
#                      발생시각       위치         위도          경도 깊이(km)   규모   진도
# 0    2023/05/2023:11:21.2   千葉県南東沖  34°57.6′N  140°13.1′E  79 km  4.2  震度２
# 1    2023/05/2012:21:40.2  トカラ列島近海  29°55.8′N  130°02.6′E  11 km  2.3  震度１
# 2    2023/05/2011:27:55.8  トカラ列島近海  29°55.8′N  130°01.1′E   9 km  2.2  震度１
# 3    2023/05/2004:13:49.5      三陸沖  39°37.6′N  144°28.4′E  54 km  4.7  震度１
# 4    2023/05/2000:57:58.0   与那国島近海  24°21.6′N  122°59.1′E  48 km  3.2  震度１
# ..                    ...      ...        ...         ...    ...  ...  ...
# 995  2022/11/0909:18:47.7     宮城県沖  38°27.3′N  141°53.3′E  55 km  4.0  震度１
# 996  2022/11/0905:28:59.1   奄美大島近海  27°58.6′N  129°09.4′E  17 km  3.2  震度１
# 997  2022/11/0902:38:10.6    宮古島近海  24°49.2′N  125°22.7′E  49 km  3.9  震度２
# 998  2022/11/0817:38:53.7  石川県能登地方  37°30.1′N  137°12.6′E  13 km  3.0  震度１
# 999  2022/11/0814:14:00.9  トカラ列島近海  29°37.6′N  129°45.7′E   8 km  3.6  震度３
#
# [1000 rows x 7 columns]

# %%
data2.columns = ['발생일', '발생시각', '위치', '위도', '경도', '깊이(km)', '규모', '진도']
data2
# Out:
#             발생일        발생시각       위치         위도          경도 깊이(km)   규모   진도
# 0    2022/11/06  19:44:26.2    大分県中部  33°17.2′N  131°27.6′E   8 km  1.6  震度１
# 1    2022/11/06  13:23:32.0   北海道東方沖  43°14.8′N  146°51.9′E  52 km  5.4  震度３
# 2    2022/11/06  09:06:55.8    長野県南部  35°56.3′N  138°06.1′E   5 km  2.7  震度２
# 3    2022/11/06  00:32:02.0      日向灘  31°42.6′N  131°47.3′E  33 km  3.8  震度１
# 4    2022/11/05  14:49:20.6     宮城県沖  37°52.4′N  141°42.4′E  63 km  3.9  震度１
# ..          ...         ...      ...        ...         ...    ...  ...  ...
# 209  2022/09/23  11:03:32.8     苫小牧沖  41°58.3′N  141°51.1′E  44 km  2.8  震度１
# 210  2022/09/23  09:53:51.9    茨城県南部  36°04.5′N  140°12.1′E  83 km  4.7  震度３
# 211  2022/09/23  07:19:24.2  沖縄本島北西沖  26°21.3′N  125°59.1′E  26 km  4.6  震度１
# 212  2022/09/23  02:53:36.8    長野県南部  35°54.3′N  137°39.3′E  11 km  2.6  震度１
# 213  2022/09/23  00:31:33.4  石川県能登地方  37°31.2′N  137°18.4′E  13 km  2.7  震度１
#
# [214 rows x 8 columns]

# %%
data2['발생시각'] = data2['발생일'] + data2['발생시각']
data2
# Out:
#             발생일                  발생시각       위치         위도          경도 깊이(km)  \
# 0    2022/11/06  2022/11/0619:44:26.2    大分県中部  33°17.2′N  131°27.6′E   8 km
# 1    2022/11/06  2022/11/0613:23:32.0   北海道東方沖  43°14.8′N  146°51.9′E  52 km
# 2    2022/11/06  2022/11/0609:06:55.8    長野県南部  35°56.3′N  138°06.1′E   5 km
# 3    2022/11/06  2022/11/0600:32:02.0      日向灘  31°42.6′N  131°47.3′E  33 km
# 4    2022/11/05  2022/11/0514:49:20.6     宮城県沖  37°52.4′N  141°42.4′E  63 km
# ..          ...                   ...      ...        ...         ...    ...
# 209  2022/09/23  2022/09/2311:03:32.8     苫小牧沖  41°58.3′N  141°51.1′E  44 km
# 210  2022/09/23  2022/09/2309:53:51.9    茨城県南部  36°04.5′N  140°12.1′E  83 km
# 211  2022/09/23  2022/09/2307:19:24.2  沖縄本島北西沖  26°21.3′N  125°59.1′E  26 km
# 212  2022/09/23  2022/09/2302:53:36.8    長野県南部  35°54.3′N  137°39.3′E  11 km
# 213  2022/09/23  2022/09/2300:31:33.4  石川県能登地方  37°31.2′N  137°18.4′E  13 km
#
#       규모   진도
# 0    1.6  震度１
# ...

# %%
data2 = data2.drop('발생일', axis=1)
data2
# Out:
#                      발생시각       위치         위도          경도 깊이(km)   규모   진도
# 0    2022/11/0619:44:26.2    大分県中部  33°17.2′N  131°27.6′E   8 km  1.6  震度１
# 1    2022/11/0613:23:32.0   北海道東方沖  43°14.8′N  146°51.9′E  52 km  5.4  震度３
# 2    2022/11/0609:06:55.8    長野県南部  35°56.3′N  138°06.1′E   5 km  2.7  震度２
# 3    2022/11/0600:32:02.0      日向灘  31°42.6′N  131°47.3′E  33 km  3.8  震度１
# 4    2022/11/0514:49:20.6     宮城県沖  37°52.4′N  141°42.4′E  63 km  3.9  震度１
# ..                    ...      ...        ...         ...    ...  ...  ...
# 209  2022/09/2311:03:32.8     苫小牧沖  41°58.3′N  141°51.1′E  44 km  2.8  震度１
# 210  2022/09/2309:53:51.9    茨城県南部  36°04.5′N  140°12.1′E  83 km  4.7  震度３
# 211  2022/09/2307:19:24.2  沖縄本島北西沖  26°21.3′N  125°59.1′E  26 km  4.6  震度１
# 212  2022/09/2302:53:36.8    長野県南部  35°54.3′N  137°39.3′E  11 km  2.6  震度１
# 213  2022/09/2300:31:33.4  石川県能登地方  37°31.2′N  137°18.4′E  13 km  2.7  震度１
#
# [214 rows x 7 columns]

# %% [markdown]
# ### 데이터 병합

# %%
data = pd.concat([data1, data2], axis=0)
data
# Out:
#                      발생시각       위치         위도          경도 깊이(km)   규모   진도
# 0    2023/05/2023:11:21.2   千葉県南東沖  34°57.6′N  140°13.1′E  79 km  4.2  震度２
# 1    2023/05/2012:21:40.2  トカラ列島近海  29°55.8′N  130°02.6′E  11 km  2.3  震度１
# 2    2023/05/2011:27:55.8  トカラ列島近海  29°55.8′N  130°01.1′E   9 km  2.2  震度１
# 3    2023/05/2004:13:49.5      三陸沖  39°37.6′N  144°28.4′E  54 km  4.7  震度１
# 4    2023/05/2000:57:58.0   与那国島近海  24°21.6′N  122°59.1′E  48 km  3.2  震度１
# ..                    ...      ...        ...         ...    ...  ...  ...
# 209  2022/09/2311:03:32.8     苫小牧沖  41°58.3′N  141°51.1′E  44 km  2.8  震度１
# 210  2022/09/2309:53:51.9    茨城県南部  36°04.5′N  140°12.1′E  83 km  4.7  震度３
# 211  2022/09/2307:19:24.2  沖縄本島北西沖  26°21.3′N  125°59.1′E  26 km  4.6  震度１
# 212  2022/09/2302:53:36.8    長野県南部  35°54.3′N  137°39.3′E  11 km  2.6  震度１
# 213  2022/09/2300:31:33.4  石川県能登地方  37°31.2′N  137°18.4′E  13 km  2.7  震度１
#
# [1214 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# 발생시각      0
# 위치        0
# 위도        0
# 경도        0
# 깊이(km)    0
# 규모        0
# 진도        0
# dtype: int64

# %%
def clean_location(data):
    # "°"와 "N"을 빈 문자열로 대체하여 제거
    cleaned_location = data.replace("°", ".").replace("′N", "")
    return cleaned_location

# 'Location' 컬럼에 apply() 함수 적용
data['위도'] = data['위도'].apply(clean_location)

# %%
def clean_location(data):
    # "°"와 "N"을 빈 문자열로 대체하여 제거
    cleaned_location = data.replace("°", ".").replace("N", "")
    return cleaned_location

# 'Location' 컬럼에 apply() 함수 적용
data['위도'] = data['위도'].apply(clean_location)

# %%
data
# Out:
#                      발생시각       위치       위도         경도 깊이(km)   규모 진도
# 0    2023/05/2023:11:21.2   千葉県南東沖  34.57.6  140.13.1E  79 km  4.2  ２
# 1    2023/05/2012:21:40.2  トカラ列島近海  29.55.8  130.02.6E  11 km  2.3  １
# 2    2023/05/2011:27:55.8  トカラ列島近海  29.55.8  130.01.1E   9 km  2.2  １
# 3    2023/05/2004:13:49.5      三陸沖  39.37.6  144.28.4E  54 km  4.7  １
# 4    2023/05/2000:57:58.0   与那国島近海  24.21.6  122.59.1E  48 km  3.2  １
# ..                    ...      ...      ...        ...    ...  ... ..
# 209  2022/09/2311:03:32.8     苫小牧沖  41.58.3  141.51.1E  44 km  2.8  １
# 210  2022/09/2309:53:51.9    茨城県南部  36.04.5  140.12.1E  83 km  4.7  ３
# 211  2022/09/2307:19:24.2  沖縄本島北西沖  26.21.3  125.59.1E  26 km  4.6  １
# 212  2022/09/2302:53:36.8    長野県南部  35.54.3  137.39.3E  11 km  2.6  １
# 213  2022/09/2300:31:33.4  石川県能登地方  37.31.2  137.18.4E  13 km  2.7  １
#
# [1214 rows x 7 columns]

# %%
def clean_location(data):
    # "°"와 "N"을 빈 문자열로 대체하여 제거
    cleaned_location = data.replace("°", ".").replace("′E", "")
    return cleaned_location

# 'Location' 컬럼에 apply() 함수 적용
data['경도'] = data['경도'].apply(clean_location)

# %%
def clean_location(data):
    # "°"와 "N"을 빈 문자열로 대체하여 제거
    cleaned_location = data.replace("°", ".").replace("E", "")
    return cleaned_location

# 'Location' 컬럼에 apply() 함수 적용
data['경도'] = data['경도'].apply(clean_location)

# %%
data
# Out:
#                      발생시각       위치       위도        경도 깊이(km)   규모 진도
# 0    2023/05/2023:11:21.2   千葉県南東沖  34.57.6  140.13.1  79 km  4.2  ２
# 1    2023/05/2012:21:40.2  トカラ列島近海  29.55.8  130.02.6  11 km  2.3  １
# 2    2023/05/2011:27:55.8  トカラ列島近海  29.55.8  130.01.1   9 km  2.2  １
# 3    2023/05/2004:13:49.5      三陸沖  39.37.6  144.28.4  54 km  4.7  １
# 4    2023/05/2000:57:58.0   与那国島近海  24.21.6  122.59.1  48 km  3.2  １
# ..                    ...      ...      ...       ...    ...  ... ..
# 209  2022/09/2311:03:32.8     苫小牧沖  41.58.3  141.51.1  44 km  2.8  １
# 210  2022/09/2309:53:51.9    茨城県南部  36.04.5  140.12.1  83 km  4.7  ３
# 211  2022/09/2307:19:24.2  沖縄本島北西沖  26.21.3  125.59.1  26 km  4.6  １
# 212  2022/09/2302:53:36.8    長野県南部  35.54.3  137.39.3  11 km  2.6  １
# 213  2022/09/2300:31:33.4  石川県能登地方  37.31.2  137.18.4  13 km  2.7  １
#
# [1214 rows x 7 columns]

# %%
def clean_location(data):
    # "°"와 "N"을 빈 문자열로 대체하여 제거
    cleaned_location = data.replace("震度", "")
    return cleaned_location

# 'Location' 컬럼에 apply() 함수 적용
data['진도'] = data['진도'].apply(clean_location)

# %%
data
# Out:
#                      발생시각       위치       위도        경도 깊이(km)   규모 진도
# 0    2023/05/2023:11:21.2   千葉県南東沖  34.57.6  140.13.1  79 km  4.2  ２
# 1    2023/05/2012:21:40.2  トカラ列島近海  29.55.8  130.02.6  11 km  2.3  １
# 2    2023/05/2011:27:55.8  トカラ列島近海  29.55.8  130.01.1   9 km  2.2  １
# 3    2023/05/2004:13:49.5      三陸沖  39.37.6  144.28.4  54 km  4.7  １
# 4    2023/05/2000:57:58.0   与那国島近海  24.21.6  122.59.1  48 km  3.2  １
# ..                    ...      ...      ...       ...    ...  ... ..
# 209  2022/09/2311:03:32.8     苫小牧沖  41.58.3  141.51.1  44 km  2.8  １
# 210  2022/09/2309:53:51.9    茨城県南部  36.04.5  140.12.1  83 km  4.7  ３
# 211  2022/09/2307:19:24.2  沖縄本島北西沖  26.21.3  125.59.1  26 km  4.6  １
# 212  2022/09/2302:53:36.8    長野県南部  35.54.3  137.39.3  11 km  2.6  １
# 213  2022/09/2300:31:33.4  石川県能登地方  37.31.2  137.18.4  13 km  2.7  １
#
# [1214 rows x 7 columns]

# %%
def clean_location(data):
    # "°"와 "N"을 빈 문자열로 대체하여 제거
    parts = data.split('.')
    cleaned_data = parts[0] + '.' + parts[1]
    return cleaned_data

# 'Location' 컬럼에 apply() 함수 적용
data['위도'] = data['위도'].apply(clean_location)





# 샘플 문자열
# data = "34.57.6"

# 문자열을 "." (점)을 기준으로 분할
# parts = data.split('.')

# 두 번째 "." 이하의 값 제거
# cleaned_data = parts[0] + '.' + parts[1]

# 결과 확인
# print(cleaned_data)

# %%
data
# Out:
#                      발생시각       위치     위도        경도 깊이(km)   규모 진도
# 0    2023/05/2023:11:21.2   千葉県南東沖  34.57  140.13.1  79 km  4.2  ２
# 1    2023/05/2012:21:40.2  トカラ列島近海  29.55  130.02.6  11 km  2.3  １
# 2    2023/05/2011:27:55.8  トカラ列島近海  29.55  130.01.1   9 km  2.2  １
# 3    2023/05/2004:13:49.5      三陸沖  39.37  144.28.4  54 km  4.7  １
# 4    2023/05/2000:57:58.0   与那国島近海  24.21  122.59.1  48 km  3.2  １
# ..                    ...      ...    ...       ...    ...  ... ..
# 209  2022/09/2311:03:32.8     苫小牧沖  41.58  141.51.1  44 km  2.8  １
# 210  2022/09/2309:53:51.9    茨城県南部  36.04  140.12.1  83 km  4.7  ３
# 211  2022/09/2307:19:24.2  沖縄本島北西沖  26.21  125.59.1  26 km  4.6  １
# 212  2022/09/2302:53:36.8    長野県南部  35.54  137.39.3  11 km  2.6  １
# 213  2022/09/2300:31:33.4  石川県能登地方  37.31  137.18.4  13 km  2.7  １
#
# [1214 rows x 7 columns]

# %%
def clean_location(data):
    # "°"와 "N"을 빈 문자열로 대체하여 제거
    parts = data.split('.')
    cleaned_data = parts[0] + '.' + parts[1]
    return cleaned_data

# 'Location' 컬럼에 apply() 함수 적용
data['경도'] = data['경도'].apply(clean_location)

# %%
data
# Out:
#                      발생시각       위치     위도      경도 깊이(km)   규모 진도
# 0    2023/05/2023:11:21.2   千葉県南東沖  34.57  140.13  79 km  4.2  ２
# 1    2023/05/2012:21:40.2  トカラ列島近海  29.55  130.02  11 km  2.3  １
# 2    2023/05/2011:27:55.8  トカラ列島近海  29.55  130.01   9 km  2.2  １
# 3    2023/05/2004:13:49.5      三陸沖  39.37  144.28  54 km  4.7  １
# 4    2023/05/2000:57:58.0   与那国島近海  24.21  122.59  48 km  3.2  １
# ..                    ...      ...    ...     ...    ...  ... ..
# 209  2022/09/2311:03:32.8     苫小牧沖  41.58  141.51  44 km  2.8  １
# 210  2022/09/2309:53:51.9    茨城県南部  36.04  140.12  83 km  4.7  ３
# 211  2022/09/2307:19:24.2  沖縄本島北西沖  26.21  125.59  26 km  4.6  １
# 212  2022/09/2302:53:36.8    長野県南部  35.54  137.39  11 km  2.6  １
# 213  2022/09/2300:31:33.4  石川県能登地方  37.31  137.18  13 km  2.7  １
#
# [1214 rows x 7 columns]

# %%
def clean_location(data):
    # "°"와 "N"을 빈 문자열로 대체하여 제거
    cleaned_location = data.replace("km", "")
    return cleaned_location

# 'Location' 컬럼에 apply() 함수 적용
data['깊이(km)'] = data['깊이(km)'].apply(clean_location)

# %%
data
# Out:
#                      발생시각       위치     위도      경도 깊이(km)   규모 진도
# 0    2023/05/2023:11:21.2   千葉県南東沖  34.57  140.13    79   4.2  ２
# 1    2023/05/2012:21:40.2  トカラ列島近海  29.55  130.02    11   2.3  １
# 2    2023/05/2011:27:55.8  トカラ列島近海  29.55  130.01     9   2.2  １
# 3    2023/05/2004:13:49.5      三陸沖  39.37  144.28    54   4.7  １
# 4    2023/05/2000:57:58.0   与那国島近海  24.21  122.59    48   3.2  １
# ..                    ...      ...    ...     ...    ...  ... ..
# 209  2022/09/2311:03:32.8     苫小牧沖  41.58  141.51    44   2.8  １
# 210  2022/09/2309:53:51.9    茨城県南部  36.04  140.12    83   4.7  ３
# 211  2022/09/2307:19:24.2  沖縄本島北西沖  26.21  125.59    26   4.6  １
# 212  2022/09/2302:53:36.8    長野県南部  35.54  137.39    11   2.6  １
# 213  2022/09/2300:31:33.4  石川県能登地方  37.31  137.18    13   2.7  １
#
# [1214 rows x 7 columns]

# %%
def clean_location(data):
    # "°"와 "N"을 빈 문자열로 대체하여 제거
    cleaned_location = data.replace("弱", "")
    return cleaned_location

# 'Location' 컬럼에 apply() 함수 적용
data['진도'] = data['진도'].apply(clean_location)

# %%
def clean_location(data):
    # "°"와 "N"을 빈 문자열로 대체하여 제거
    cleaned_location = data.replace("強", "")
    return cleaned_location

# 'Location' 컬럼에 apply() 함수 적용
data['진도'] = data['진도'].apply(clean_location)

# %%
data
# Out:
#                      발생시각       위치     위도      경도 깊이(km)   규모 진도
# 0    2023/05/2023:11:21.2   千葉県南東沖  34.57  140.13    79   4.2  ２
# 1    2023/05/2012:21:40.2  トカラ列島近海  29.55  130.02    11   2.3  １
# 2    2023/05/2011:27:55.8  トカラ列島近海  29.55  130.01     9   2.2  １
# 3    2023/05/2004:13:49.5      三陸沖  39.37  144.28    54   4.7  １
# 4    2023/05/2000:57:58.0   与那国島近海  24.21  122.59    48   3.2  １
# ..                    ...      ...    ...     ...    ...  ... ..
# 209  2022/09/2311:03:32.8     苫小牧沖  41.58  141.51    44   2.8  １
# 210  2022/09/2309:53:51.9    茨城県南部  36.04  140.12    83   4.7  ３
# 211  2022/09/2307:19:24.2  沖縄本島北西沖  26.21  125.59    26   4.6  １
# 212  2022/09/2302:53:36.8    長野県南部  35.54  137.39    11   2.6  １
# 213  2022/09/2300:31:33.4  石川県能登地方  37.31  137.18    13   2.7  １
#
# [1214 rows x 7 columns]

# %%
data = data[~data['규모'].str.contains('不明')]

# %%
data
# Out:
#                      발생시각       위치     위도      경도 깊이(km)   규모 진도
# 0    2023/05/2023:11:21.2   千葉県南東沖  34.57  140.13    79   4.2  ２
# 1    2023/05/2012:21:40.2  トカラ列島近海  29.55  130.02    11   2.3  １
# 2    2023/05/2011:27:55.8  トカラ列島近海  29.55  130.01     9   2.2  １
# 3    2023/05/2004:13:49.5      三陸沖  39.37  144.28    54   4.7  １
# 4    2023/05/2000:57:58.0   与那国島近海  24.21  122.59    48   3.2  １
# ..                    ...      ...    ...     ...    ...  ... ..
# 209  2022/09/2311:03:32.8     苫小牧沖  41.58  141.51    44   2.8  １
# 210  2022/09/2309:53:51.9    茨城県南部  36.04  140.12    83   4.7  ３
# 211  2022/09/2307:19:24.2  沖縄本島北西沖  26.21  125.59    26   4.6  １
# 212  2022/09/2302:53:36.8    長野県南部  35.54  137.39    11   2.6  １
# 213  2022/09/2300:31:33.4  石川県能登地方  37.31  137.18    13   2.7  １
#
# [1187 rows x 7 columns]

# %%
data['발생시각'] = data['발생시각'].str[:10]
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_21872\1750063870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['발생시각'] = data['발생시각'].str[:10]

# %%
data
# Out:
#            발생시각       위치     위도      경도 깊이(km)   규모 진도
# 0    2023/05/20   千葉県南東沖  34.57  140.13    79   4.2  ２
# 1    2023/05/20  トカラ列島近海  29.55  130.02    11   2.3  １
# 2    2023/05/20  トカラ列島近海  29.55  130.01     9   2.2  １
# 3    2023/05/20      三陸沖  39.37  144.28    54   4.7  １
# 4    2023/05/20   与那国島近海  24.21  122.59    48   3.2  １
# ..          ...      ...    ...     ...    ...  ... ..
# 209  2022/09/23     苫小牧沖  41.58  141.51    44   2.8  １
# 210  2022/09/23    茨城県南部  36.04  140.12    83   4.7  ３
# 211  2022/09/23  沖縄本島北西沖  26.21  125.59    26   4.6  １
# 212  2022/09/23    長野県南部  35.54  137.39    11   2.6  １
# 213  2022/09/23  石川県能登地方  37.31  137.18    13   2.7  １
#
# [1187 rows x 7 columns]

# %%
# 컬럼 이름을 변경할 새로운 이름 지정
new_column_names = {'발생시각': 'OT',
                    '위치': 'SPOT',
                   '위도':'LAT',
                   '경도':'LON',
                   '깊이(km)':'DEP',
                   '규모':'MT',
                   '진도':'SC'}

# 컬럼 이름 변경
data.rename(columns=new_column_names, inplace=True)
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_21872\1477416182.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns=new_column_names, inplace=True)

# %%
data
# Out:
#              OT     SPOT    LAT     LON  DEP   MT SC
# 0    2023/05/20   千葉県南東沖  34.57  140.13  79   4.2  ２
# 1    2023/05/20  トカラ列島近海  29.55  130.02  11   2.3  １
# 2    2023/05/20  トカラ列島近海  29.55  130.01   9   2.2  １
# 3    2023/05/20      三陸沖  39.37  144.28  54   4.7  １
# 4    2023/05/20   与那国島近海  24.21  122.59  48   3.2  １
# ..          ...      ...    ...     ...  ...  ... ..
# 209  2022/09/23     苫小牧沖  41.58  141.51  44   2.8  １
# 210  2022/09/23    茨城県南部  36.04  140.12  83   4.7  ３
# 211  2022/09/23  沖縄本島北西沖  26.21  125.59  26   4.6  １
# 212  2022/09/23    長野県南部  35.54  137.39  11   2.6  １
# 213  2022/09/23  石川県能登地方  37.31  137.18  13   2.7  １
#
# [1187 rows x 7 columns]

# %%
data.to_excel('J_2023.xlsx', index=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1187 entries, 0 to 213
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   OT      1187 non-null   object
#  1   SPOT    1187 non-null   object
#  2   LAT     1187 non-null   object
#  3   LON     1187 non-null   object
#  4   DEP     1187 non-null   object
#  5   MT      1187 non-null   object
#  6   SC      1187 non-null   object
# dtypes: object(7)
# memory usage: 74.2+ KB

# %%
data['OT'] = pd.to_datetime(data['OT'])
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_21872\2131428569.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['OT'] = pd.to_datetime(data['OT'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1187 entries, 0 to 213
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   OT      1187 non-null   datetime64[ns]
#  1   SPOT    1187 non-null   object
#  2   LAT     1187 non-null   object
#  3   LON     1187 non-null   object
#  4   DEP     1187 non-null   object
#  5   MT      1187 non-null   object
#  6   SC      1187 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 74.2+ KB

# %%
data = data.astype({'LAT':'float'})

# %%
data = data.astype({'LON':'float'})

# %%
data = data.astype({'DEP':'float'})

# %%
data = data.astype({'MT':'float'})

# %%
data = data.astype({'SC':'float'})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1187 entries, 0 to 213
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   OT      1187 non-null   datetime64[ns]
#  1   SPOT    1187 non-null   object
#  2   LAT     1187 non-null   float64
#  3   LON     1187 non-null   float64
#  4   DEP     1187 non-null   float64
#  5   MT      1187 non-null   float64
#  6   SC      1187 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 74.2+ KB

# %%
x = ((data['LON'] >= 121) & (data['LON'] < 141)).sum()
x
# Out:
# 882

# %%
min_value = 121
max_value = 141

# 조건을 만족하는 행을 선택하고 삭제
data = data[(data['LON'] >= min_value) & (data['LON'] <= max_value)]

# %%
data
# Out:
#             OT     SPOT    LAT     LON   DEP   MT   SC
# 0   2023-05-20   千葉県南東沖  34.57  140.13  79.0  4.2  2.0
# 1   2023-05-20  トカラ列島近海  29.55  130.02  11.0  2.3  1.0
# 2   2023-05-20  トカラ列島近海  29.55  130.01   9.0  2.2  1.0
# 4   2023-05-20   与那国島近海  24.21  122.59  48.0  3.2  1.0
# 5   2023-05-19  トカラ列島近海  29.56  130.01  10.0  2.1  1.0
# ..         ...      ...    ...     ...   ...  ...  ...
# 207 2022-09-24   兵庫県南東部  34.47  135.19   9.0  4.0  3.0
# 210 2022-09-23    茨城県南部  36.04  140.12  83.0  4.7  3.0
# 211 2022-09-23  沖縄本島北西沖  26.21  125.59  26.0  4.6  1.0
# 212 2022-09-23    長野県南部  35.54  137.39  11.0  2.6  1.0
# 213 2022-09-23  石川県能登地方  37.31  137.18  13.0  2.7  1.0
#
# [886 rows x 7 columns]

# %%
data.to_excel('Japan_2023earthquake.xlsx', index=False)

# %%
new_column_order = ['OT', 'MT', 'DEP', 'SC', 'LAT', 'LON', 'SPOT']
data = data[new_column_order]
data
# Out:
#             OT   MT   DEP   SC    LAT     LON     SPOT
# 0   2023-05-20  4.2  79.0  2.0  34.57  140.13   千葉県南東沖
# 1   2023-05-20  2.3  11.0  1.0  29.55  130.02  トカラ列島近海
# 2   2023-05-20  2.2   9.0  1.0  29.55  130.01  トカラ列島近海
# 4   2023-05-20  3.2  48.0  1.0  24.21  122.59   与那国島近海
# 5   2023-05-19  2.1  10.0  1.0  29.56  130.01  トカラ列島近海
# ..         ...  ...   ...  ...    ...     ...      ...
# 207 2022-09-24  4.0   9.0  3.0  34.47  135.19   兵庫県南東部
# 210 2022-09-23  4.7  83.0  3.0  36.04  140.12    茨城県南部
# 211 2022-09-23  4.6  26.0  1.0  26.21  125.59  沖縄本島北西沖
# 212 2022-09-23  2.6  11.0  1.0  35.54  137.39    長野県南部
# 213 2022-09-23  2.7  13.0  1.0  37.31  137.18  石川県能登地方
#
# [886 rows x 7 columns]

# %%
data1 = data[['DEP', 'SC', 'LAT', 'LON']]
